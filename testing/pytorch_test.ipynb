# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Compiled CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
x = torch.rand(1000, 1000, device="cuda")
y = torch.mm(x, x)
print("Result:", y.shape, "on", y.device)
# Out:
# Torch version: 2.10.0.dev20251123+cu128
# CUDA available: True
# Compiled CUDA: 12.8
# GPU: NVIDIA GeForce RTX 5080 Laptop GPU
# Result: torch.Size([1000, 1000]) on cuda:0

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("../backend/models/text")
print(model.get_sentence_embedding_dimension())
# Out:
# 768

# %%
import bitsandbytes as bnb
print(bnb.__version__)
# Out:
# 0.48.2

# %%
import base64

with open("test_images/Aconitum_heterophyllum_test.jpg", "rb") as f:
    b64 = base64.b64encode(f.read()).decode()

print(b64)
# Out:
# ...

# %%
import base64

with open("test_images/Aesculus_indica_test.jpg", "rb") as f:
    b64 = base64.b64encode(f.read()).decode()

print(b64)
# Out:
# ...
